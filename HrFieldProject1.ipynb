# %% [markdown]
# # importing numpy,pandas,matplotlib,seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#reading data
train=pd.read_csv("trainhr.csv")
test=pd.read_csv("testhr.csv")

# %%
#getting shape of data sets
print("Shape of train:",train.shape)
print("Shape of test:",test.shape)
# Out:
# Shape of train: (54808, 14)
# Shape of test: (23490, 13)

# %%
#Getting head of train and test
test.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# 1                  5              0            0                  51
# 2                  4              0            0                  47
# 3                  9              0            0                  65
# 4                  7              0            0                  61

# %%
train.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
#describing training dataset
train.describe(include='all')
# Out:
#          employee_id         department    region   education gender  \
# count   54808.000000              54808     54808       52399  54808
# unique           NaN                  9        34           3      2
# top              NaN  Sales & Marketing  region_2  Bachelor's      m
# freq             NaN              16840     12343       36669  38496
# mean    39195.830627                NaN       NaN         NaN    NaN
# std     22586.581449                NaN       NaN         NaN    NaN
# min         1.000000                NaN       NaN         NaN    NaN
# 25%     19669.750000                NaN       NaN         NaN    NaN
# 50%     39225.500000                NaN       NaN         NaN    NaN
# 75%     58730.500000                NaN       NaN         NaN    NaN
# max     78298.000000                NaN       NaN         NaN    NaN
#
#        recruitment_channel  no_of_trainings           age  \
# count                54808     54808.000000  54808.000000
# unique                   3              NaN           NaN
# top                  other              NaN           NaN
# freq                 30446              NaN           NaN
# mean                   NaN         1.253011     34.803915
# std                    NaN         0.609264      7.660169
# min                    NaN         1.000000     20.000000
# 25%                    NaN         1.000000     29.000000
# 50%                    NaN         1.000000     33.000000
# 75%                    NaN         1.000000     39.000000
# max                    NaN        10.000000     60.000000
#
#         previous_year_rating  length_of_service  KPIs_met >80%   awards_won?  \
# count           50684.000000       54808.000000   54808.000000  54808.000000
# unique                   NaN                NaN            NaN           NaN
# top                      NaN                NaN            NaN           NaN
# freq                     NaN                NaN            NaN           NaN
# mean                3.329256           5.865512       0.351974      0.023172
# std                 1.259993           4.265094       0.477590      0.150450
# min                 1.000000           1.000000       0.000000      0.000000
# 25%                 3.000000           3.000000       0.000000      0.000000
# 50%                 3.000000           5.000000       0.000000      0.000000
# 75%                 4.000000           7.000000       1.000000      0.000000
# max                 5.000000          37.000000       1.000000      1.000000
#
#         avg_training_score   is_promoted
# count         54808.000000  54808.000000
# unique                 NaN           NaN
# top                    NaN           NaN
# freq                   NaN           NaN
# mean             63.386750      0.085170
# std              13.371559      0.279137
# min              39.000000      0.000000
# 25%              51.000000      0.000000
# 50%              60.000000      0.000000
# 75%              76.000000      0.000000
# max              99.000000      1.000000

# %%
#getting info of train dataset
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.9+ MB

# %%
train.isnull().any()
# Out:
# employee_id             False
# department              False
# region                  False
# education                True
# gender                  False
# recruitment_channel     False
# no_of_trainings         False
# age                     False
# previous_year_rating     True
# length_of_service       False
# KPIs_met >80%           False
# awards_won?             False
# avg_training_score      False
# is_promoted             False
# dtype: bool

# %%
test.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\python\lib\site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\python\lib\site-packages (from wordcloud) (1.23.0)
# Requirement already satisfied: pillow in c:\python\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\python\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\python\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\lib\site-packages (from matplotlib->wordcloud) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\lib\site-packages (from matplotlib->wordcloud) (1.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\python\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\python\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\python\python.exe -m pip install --upgrade pip' command.

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {"didn't", "isn't", 'with', 'above', 'so', 'where', "they've", 'then', 'than', 'in', 'all', 'at', 'ought', 'should', 'only', "why's", 'me', 'my', 'myself', "i'll", 'most', "he'll", "how's", 'while', "who's", 'also', 'more', 'just', 'some', 'against', "i'd", 'what', 'doing', "can't", "let's", 'get', "we'll", 'and', 'theirs', 'r', 'could', 'like', 'if', 'they', 'him', "wouldn't", 'can', 'i', 'own', "they'll", 'you', 'under', 'otherwise', 'your', "hasn't", "mustn't", "you're", 'again', 'for', 'however', "she'd", 'their', 'her', 'http', "they'd", "don't", 'our', "we're", "doesn't", 'same', 'that', 'am', 'since', 'by', 'whom', 'his', 'up', "you'd", 'but', 'each', "she'll", "what's", "we've", "when's", 'he', "you'll", 'has', "shouldn't", "there's", 'are', 'before', 'into', 'those', 'had', "you've", 'com', 'how', 'yours', 'yourself', 'shall', 'yourselves', 'itself', 'any', 'being', "hadn't", 'ourselves', 'is', "he's", 'k', 'out', 'too', "here's", 'hence', 'when', 'herself', 'been', 'hers', "haven't", "shan't", 'himself', "couldn't", 'the', 'here', 'these', "they're", 'were', 'not', 'to', 'of', 'or', 'about', 'would', "we'd", 'few', 'which', 'until', 'a', 'over', 'below', "won't", 'between', 'other', 'she', 'this', "wasn't", "i've", 'there', 'an', 'have', "aren't", 'both', 'cannot', 'ever', 'because', 'very', 'why', 'through', 'therefore', "she's", "he'd", 'no', 'nor', 'ours', "that's", 'during', 'who', "where's", "weren't", 'does', 'its', 'after', 'having', 'them', 'it', 'off', 'as', 'from', 'once', 'do', 'we', "i'm", 'themselves', 'on', 'be', 'did', 'such', 'further', 'down', 'was', 'www', "it's", 'else'}

# %%
stopword=set(STOPWORDS)
wordcloud=WordCloud(background_color='white',stopwords=stopword).generate(str(train["department"]))
plt.rcParams['figure.figsize']=(12,8)
print(wordcloud)
plt.title('Most Popular Departments',fontsize=30)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001E977BE7E80>

# %%
#checking no of employees promoted
train['is_promoted'].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
#finding the %age of employees promoted
promoted=(4668/54808)*100
print("percentage of employee promoted is{:.2f}%".format(promoted))
# Out:
# percentage of employee promoted is8.52%

# %%
#plotting a scatter plot
plt.hist(train['is_promoted'])
plt.title('plot to show gap between promoted and non promoted employees',fontsize=30)
plt.xlabel('0 - non-promoted and 1-promoted',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.show()

# %%
#checking dist of avg training score
plt.rcParams['figure.figsize']=(12,7)
sns.histplot(train['avg_training_score'],color='blue')
plt.title("Distribution of training score among employees",fontsize=30)
plt.xlabel('Average Training Score',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.show()

# %%
#Counting the number of persons who have won the award
train['awards_won?'].value_counts()
# Out:
# 0    53538
# 1     1270
# Name: awards_won?, dtype: int64

# %%
#plotting pie chart
size=[53538,1270]
colors=['cyan','blue']
labels=["No Award won","Award won"]
my_circle=plt.Circle((0,0),0.7,color='white')
plt.rcParams['figure.figsize']=(9,9)
plt.pie(size,colors=colors,labels=labels,shadow=True,autopct="%.2f%%")
plt.title('%ge of employees who won award',fontsize=30)
plt.show()

# %%
size=[53538,1270]
colors=['cyan','blue']
labels=["No Award won","Award won"]
my_circle=plt.Circle((0,0),0.7,color='white')
plt.rcParams['figure.figsize']=(9,9)
plt.pie(size,colors=colors,labels=labels,shadow=True,autopct="%.2f%%")
plt.title('%ge of employees who won award',fontsize=30)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %%
#checking the distribution of length of service
plt.subplots(figsize=(15,8))
sns.histplot(train['length_of_service'],color='green')
plt.title('Distribution of length of service among the Employees',fontsize=30)
plt.xlabel('Length of service in years')
plt.ylabel('count')
plt.show()

# %%
#checking dist of age of employees in company
plt.subplots(figsize=(15,5))
sns.histplot(train['age'])
plt.title('Distribution of Age of Employee',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Distribution of Age of Employee')

# %%
#checking the different no. of training done by the employees
train['no_of_trainings'].value_counts()
# Out:
# 1     44378
# 2      7987
# 3      1776
# 4       468
# 5       128
# 6        44
# 7        12
# 8         5
# 10        5
# 9         5
# Name: no_of_trainings, dtype: int64

# %%
#checking the different types of recruitent channels for the company
train['recruitment_channel'].value_counts()
# Out:
# other       30446
# sourcing    23220
# referred     1142
# Name: recruitment_channel, dtype: int64

# %%
#plotting a donut chart for visualizing each of the recruitment channel's share
size = [30446,23220,1142]
colors = ['black','red','blue']
labels = "Others","Sourcing","Reffered"

my_circle = plt.Circle((0,0),0.7,color='white')

plt.rcParams['figure.figsize']=(9,9)
plt.pie(size,colors=colors,labels=labels,shadow=True,autopct='%.2f%%')
plt.title('Showing Share of different Channels',fontsize=30)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %%
#checking the most popular education degreee among the employees
stopword=set(STOPWORDS)
wordcloud=WordCloud(max_words=5,stopwords=stopword).generate(str(train["education"]))
plt.rcParams['figure.figsize']=(15,8)
print(wordcloud)
plt.title('Most Popular Degrees among Employees',fontsize=30)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001E9779D7580>

# %%
#checking the gender gap
train['gender'].value_counts()
# Out:
# m    38496
# f    16312
# Name: gender, dtype: int64

# %%
#plotting a pie chart
size=[38496,16312]
labels="Male","Female"
colors=['yellow','orange']
explode=[0,0.1]

plt.subplots(figsize=(8,8))
plt.pie(size,labels=labels,colors=colors,explode=explode,shadow=True,autopct="%.2f%%")
plt.title('A Pie Chart Representing Gendergap',fontsize=30)
plt.axis('off')
plt.legend()
plt.show()

# %%
#checking the different regions of company
plt.subplots(figsize=(15,5))
sns.countplot(train['region'],color='red')
plt.title('Different Regions in the Company',fontsize=30)
plt.xticks(rotation=60)
plt.xlabel('Region Code')
plt.ylabel('count')
plt.show()
# Out:
# C:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#scatter plot between average training score and is_promoted
data = pd.crosstab(train['avg_training_score'],train['is_promoted'])
data.div(data.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(20,9),color=['darkred','lightgreen'])
plt.title('Looking at the Dependency of Training Score in promotion',fontsize=30)
plt.xlabel('Average Training Scores',fontsize=15)
plt.legend()
plt.show()

# %%
#As the training Scores increases,chances of promotion Increases Highly

# %%
#Checking dependency of different regions in promotion
data = pd.crosstab(train['region'],train['is_promoted'])
data.div(data.sum(1).astype('float'),axis=0).plot(kind='bar',stacked=True,figsize=(20,8),color=['lightblue','purple'])
plt.title('Dependency of Regions in determining promotion of Employees',fontsize=30)
plt.xlabel('Different Regions of the Company',fontsize=20)
plt.legend()
plt.show()

# %%
#dependency of awards won on promotion
data = pd.crosstab(train['awards_won?'],train['is_promoted'])
data.div(data.sum(1).astype('float'),axis=0).plot(kind='bar',stacked=True,figsize=(10,8),color=['magenta','purple'])
plt.title('Dependency of Awards in determining promotion',fontsize=30)
plt.xlabel('Awards Won or Not',fontsize=20)
plt.legend()
plt.show()

# %%
#checking dependency of age factor in promotion of employees
data = pd.crosstab(train['age'],train['is_promoted'])
data.div(data.sum(1).astype('float'),axis=0).plot(kind='bar',stacked=True,figsize=(20,8),color=['red','green'])
plt.title('Dependency of Age in determining Promotion of Employees ',fontsize=30)
plt.xlabel('Age of Employees',fontsize=20)
plt.legend()
plt.show()

# %%
#Checking which department got the greatest number of promotion
data = pd.crosstab(train['department'],train['is_promoted'])
data.div(data.sum(1).astype('float'),axis=0).plot(kind='bar',stacked=True,figsize=(20,8),color=['orange','green'])
plt.title('Dependency of Departments in determining Promotion of Employees ',fontsize=30)
plt.xlabel('Different Departments of the Company',fontsize=20)
plt.legend()
plt.show()

# %%
#Checking dependency of gender over promotion
data = pd.crosstab(train['gender'],train['is_promoted'])
data.div(data.sum(1).astype('float'),axis=0).plot(kind='bar',stacked=True,figsize=(7,5),color=['pink','yellow'])
plt.title('Dependency of Genders in determining Promotion of Employees ',fontsize=30)
plt.xlabel('Gender',fontsize=30)
plt.legend()
plt.show()
